# %%
import numpy as np 
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')
credits = pd.read_csv('credits.csv')

# %%
movies.head(5).T
# Out:
#                                                                       0  \
# budget                                                        237000000
# genres                [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                    http://www.avatarmovie.com/
# id                                                                19995
# keywords              [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                    en
# original_title                                                   Avatar
# overview              In the 22nd century, a paraplegic Marine is di...
# popularity                                                   150.437577
# production_companies  [{"name": "Ingenious Film Partners", "id": 289...
# production_countries  [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                 2009-12-10
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
movies.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.790000e+03    4790.000000  4790.000000  4.790000e+03  4788.000000
# mean   2.912351e+07   56562.665971    21.550542  8.248389e+07   107.094403
# std    4.074971e+07   87918.737653    31.840126  1.630215e+08    22.153713
# min    0.000000e+00       5.000000     0.000372  0.000000e+00     0.000000
# 25%    8.538825e+05    9008.250000     4.746796  0.000000e+00    94.000000
# 50%    1.500000e+07   14577.500000    12.976720  1.929452e+07   104.000000
# 75%    4.000000e+07   58050.250000    28.386165  9.327355e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count       movie_id      cluster
# count   4790.000000   4790.000000    4790.000000  4790.000000
# mean       6.105115    692.087474   56562.665971     7.510856
# std        1.163444   1235.737955   87918.737653     5.307204
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ast

# Load data
df = pd.read_csv("movies.csv")

# Helper to count list-like items
def safe_count(val):
    if pd.isnull(val):
        return 0
    try:
        return len(ast.literal_eval(val))
    except:
        return 0

# Feature Engineering
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')
df['release_year'] = df['release_date'].dt.year
df['title_length'] = df['title'].fillna('').apply(len)
df['num_genres'] = df['genres'].apply(safe_count)
df['num_keywords'] = df['keywords'].apply(safe_count)
df['num_production_companies'] = df['production_companies'].apply(safe_count)
df['overview_length'] = df['overview'].fillna('').apply(lambda x: len(x.split()))
df['has_tagline'] = df['tagline'].notnull().astype(int)
df['profit'] = df['revenue'] - df['budget']
df['roi'] = np.where(df['budget'] != 0, df['revenue'] / df['budget'], np.nan)
df['log_budget'] = np.log1p(df['budget'])
df['log_revenue'] = np.log1p(df['revenue'])

# Select features for correlation
features = [
    'budget', 'log_budget', 'revenue', 'log_revenue', 'profit', 'roi',
    'popularity', 'runtime', 'vote_average', 'vote_count',
    'has_tagline', 'release_year',
    'num_keywords', 'num_genres', 'num_production_companies', 'overview_length', 'title_length'
]

# Drop rows with missing values in selected features
df_corr = df[features].dropna()

# Compute correlation matrix
corr_matrix = df_corr.corr()

# Plot correlation heatmap
plt.figure(figsize=(14, 12))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, cbar=True)
plt.title("Enhanced Correlation Heatmap for Movie Dataset", fontsize=16)
plt.tight_layout()
plt.show()

# %%
import ast

# %%
#THIS FUNCTION IS USED TO CONVERT THE LIST OF DICTIONARY TO DICTIONARY
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name']) 
    return L

# %%
movies.dropna(inplace=True)

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
#IT CONVERT STRING INTO DICTIONARIES OF LIST
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.sample(5)
# Out:
#       movie_id                                title  \
# 1643      2122                  The Whole Ten Yards
# 4734     18841         The Lost Skeleton of Cadavra
# 114        674  Harry Potter and the Goblet of Fire
# 1168      6114                              Dracula
# 1734     15198                      Mystery, Alaska
#
#                                                overview  \
# 1643  Jimmy 'The Tulip' Tudeski now spends his days ...
# 4734  Remember the good old days when anyone with a ...
# 114   Harry starts his fourth year at Hogwarts, comp...
# 1168  When Dracula leaves the captive Jonathan Harke...
# 1734  In Mystery, Alaska, life revolves around the l...
#
#                                  genres  \
# 1643          [Comedy, Thriller, Crime]
# 4734  [Comedy, Horror, Science Fiction]
# 114        [Adventure, Fantasy, Family]
# 1168                  [Romance, Horror]
# 1734                    [Drama, Comedy]
#
#                                                keywords  \
# ...

# %%
# THIS FUNCTION REMOVES ALL SPACES BETWEEN STRINGS
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
#IT SPLIT THE OVERVIEW TO LIST OF WORDS
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.08858079, 0.05905386, ..., 0.02478408, 0.02599376,
#         0.        ],
#        [0.08858079, 1.        , 0.06451613, ..., 0.02707652, 0.        ,
#         0.        ],
#        [0.05905386, 0.06451613, 1.        , ..., 0.02707652, 0.        ,
#         0.        ],
#        ...,
#        [0.02478408, 0.02707652, 0.02707652, ..., 1.        , 0.07150969,
#         0.0489116 ],
#        [0.02599376, 0.        , 0.        , ..., 0.07150969, 1.        ,
#         0.05129892],
#        [0.        , 0.        , 0.        , ..., 0.0489116 , 0.05129892,
#         1.        ]], shape=(4806, 4806))

# %%
new[new['title'] == 'The Lego Movie'].index[0]
# Out:
# np.int64(744)

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Gandhi');
# Out:
# Gandhi, My Father
# The Wind That Shakes the Barley
# A Passage to India
# Guiana 1838
# Ramanujan

# %%
import numpy as np

def avg_similarity(movie_title):
    index = new[new['title'] == movie_title].index[0]
    scores = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    top5 = scores[1:6]
    avg_score = np.mean([s[1] for s in top5])
    return round(avg_score, 4)

print("Average similarity score:", avg_similarity("The Avengers"))
# Out:
# Average similarity score: 0.3188

# %%
import pickle

# %%
pickle.dump(new,open('movie_list.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
import pandas as pd
import ast
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from scipy.sparse import hstack

# Load datasets
movies_df = pd.read_csv('movies.csv')
credits_df = pd.read_csv('credits.csv')

# Merge using correct keys
movies_df = movies_df.merge(credits_df, left_on='id', right_on='movie_id')

# Extract 'name' fields from JSON strings
def extract_names(text, key='name'):
    try:
        items = ast.literal_eval(text)
        return ' '.join([item[key] for item in items if key in item])
    except:
        return ''

# Apply extraction
movies_df['genres'] = movies_df['genres'].apply(lambda x: extract_names(x))
movies_df['keywords'] = movies_df['keywords'].apply(lambda x: extract_names(x))
movies_df['cast'] = movies_df['cast'].apply(lambda x: extract_names(x))
movies_df['crew'] = movies_df['crew'].apply(lambda x: extract_names(x))

# Combine features for clustering
movies_df['combined_features'] = (
    movies_df['genres'] + ' ' +
    movies_df['keywords'] + ' ' +
    movies_df['cast'] + ' ' +
    movies_df['crew']
)

# Hybrid vectorization (TF-IDF + CountVectorizer)
vectorizer_tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
vectorizer_count = CountVectorizer(stop_words='english', max_features=5000)

X_tfidf = vectorizer_tfidf.fit_transform(movies_df['combined_features'])
X_count = vectorizer_count.fit_transform(movies_df['combined_features'])

# Merge features
X = hstack([X_tfidf, X_count])

# Dimensionality Reduction (SVD with 300 components)
svd = TruncatedSVD(n_components=300, random_state=42)
X_reduced = svd.fit_transform(X)

# Silhouette score for different k
scores = []
clusters_range = list(range(2, 21))
for k in clusters_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10, algorithm='elkan')
    labels = km.fit_predict(X_reduced)
    score = silhouette_score(X_reduced, labels)
    scores.append(score)

# Plot silhouette scores
plt.figure(figsize=(10, 6))
plt.plot(clusters_range, scores, marker='o', linestyle='-', color='green')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('KMeans Clustering: Optimal k using Silhouette Score')
plt.grid(True)
plt.show()

# Find best k and refit model
best_k = clusters_range[scores.index(max(scores))]
print(f'Best k: {best_k} with Silhouette Score: {max(scores):.4f}')

# Final clustering with best k using Elkan algorithm (optimized for sparse data)
final_kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=10, algorithm='elkan')
movies_df['cluster'] = final_kmeans.fit_predict(X_reduced)
# Out:
# Best k: 2 with Silhouette Score: 0.3527

# %%
print(movies_df.columns)

print(movies_df[['title_y', 'genres', 'cluster']].head())
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title_x', 'vote_average',
#        'vote_count', 'movie_id', 'title_y', 'cast', 'crew',
#        'combined_features', 'cluster', 'main_genre'],
#       dtype='object')
#                                     title_y  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                      genres  cluster
# 0  Action Adventure Fantasy Science Fiction        1
# 1                  Adventure Fantasy Action        0
# 2                    Action Adventure Crime        1
# ...
